# %% [markdown]
# # Decision Tree Intuition

# %% [markdown]
# Tree-based learning algorithms are a broad and popular family of related non-parametric, supervised methods for both classification and regression. The basis of tree-based learners is the decision tree wherein a series of decision rules (such as "if their gender is male, ..." or "if today is monday, ...") are chained. The result looks vaguely like an upside-down tree, with the first decision rule at the top and subsequent decision rules spreading out below. In a decision tree, every decision rule occurs at a decision node, with the rule creating branches leading to new nodes. A branch without a decision rule at the end is called a leaf.

# %% [markdown]
# Lecture Notes from Cornell Univeristy on Decision Trees:
#
#
# https://www.cs.cornell.edu/courses/cs4780/2018fa/lectures/lecturenote17.html

# %% [markdown]
# The spilts are created using information entropy, which we are not going to focus on in this slide. We are going to focus on the pratical portion of the Decision Tree Regression and it is fine to suppose that the algorithm, that we will create using python, will create the spilts are most optimal points.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('decisiontree.jpg')
plt.imshow(img)

#I can erase this anytime. This comment is just for test purposes

# %% [markdown]
# ### Importing the Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
print(dataset)
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %% [markdown]
# Things to change if the dataset changes:
#
# 1. "X = dataset.iloc[:, 1:-1].values": 1:-1 means that only take columns starting from first to one before the last one. In our dataset, the first column was string, and we do not need it. If the first column has numeric values, then we will change 1 to 0.
#
# 2. Same goes the 4th line of code.
#
# 3. If there are some missing value in the dataset, then apply the "taking care of missing values" section to the dataset from the "Data Preprocessing Toolkit".
#
# 4. If there are categorical data, apply the appropriate tools and make the dataset useable.

# %% [markdown]
# ### Training the Decision Tree Regression model on the whole Dataset

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# In the above code cell, "random_state = 0" acts like a seed for the regressor. That means that everytime we will run these code cells, we will get the result as first time.

# %% [markdown]
# ### Predict a new result

# %%
regressor.predict([[6.5]])
# Out:
# array([150000.])

# %% [markdown]
# ### Visualising the Decision Tree Regression Results (Higher Resolution)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)

plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Truth or Bluff (Decision Tree Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# If the dimensions of the dataset are higher than 2, we need to change the visualising code cell because in this example, the the plotting only works because the dimension is 2.
